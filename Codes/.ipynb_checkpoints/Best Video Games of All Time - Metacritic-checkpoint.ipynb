# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\DataScience\Machine-Learning-Projects\Video Game Analysis\Datasets\metacritic_games 1970 - 2023\metacritic_games.csv")

# %% [markdown]
# ## About this file
#
# <h4> Common Data: </h4>
#
# <ul>
# <li>link</li>
# <li>name</li>
# <li>developer</li>
# <li>publisher</li>
# <li>summary</li>
# <li>genres</li>
# <li>rating</li>
# </ul>
#
#
# <h4> Platform Related Data:  </h4>
#
# <ul>
# <li>platform</li>
# <li>release_date</li>
# <li>metascore</li>
# <li>critic_reviews_count</li>
# <li>positive_critic_reviews_count</li>
# <li>mixed_critic_reviews_count</li>
# <li>negative_critic_reviews_count</li>
# <li>user_score</li>
# <li>user_reviews_count</li>
# <li>positive_user_reviews_count</li>
# <li>mixed_user_reviews_count</li>
# <li>negative_user_reviews_count</li>
# </ul>

# %%
df.head(3)
# Out:
#                                                 link                name  \
# 0     https://www.metacritic.com/game/sheep-village/       Sheep Village
# 1    https://www.metacritic.com/game/botball-online/      Botball Online
# 2  https://www.metacritic.com/game/far-cry-collec...  Far Cry Collection
#
#             developer           publisher  \
# 0             Success             Success
# 1  Sm4rt Game Studios  Sm4rt Game Studios
# 2    Ubisoft Montreal             Ubisoft
#
#                                              summary         genres rating  \
# 0                                                NaN  Miscellaneous    NaN
# 1  Botball is a smash-mouth, blastastic, five-on-...         Sports    NaN
# 2  FARCRY COLLECTION  Far Cry You are Jack Carver...    Compilation    NaN
#
#   platform release_date  metascore  critic_reviews_count  \
# 0       PC          NaN        NaN                   NaN
# 1       PC          NaN        NaN                   NaN
# ...

# %%
df.shape
# Out:
# (175623, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175623 entries, 0 to 175622
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   link                           175623 non-null  object
#  1   name                           175373 non-null  object
#  2   developer                      172842 non-null  object
#  3   publisher                      175239 non-null  object
#  4   summary                        133373 non-null  object
#  5   genres                         175623 non-null  object
#  6   rating                         57734 non-null   object
#  7   platform                       175623 non-null  object
#  8   release_date                   166145 non-null  object
#  9   metascore                      26143 non-null   float64
#  10  critic_reviews_count           44815 non-null   float64
#  11  positive_critic_reviews_count  30075 non-null   float64
# ...

# %%
df.describe()
# Out:
#           metascore  critic_reviews_count  positive_critic_reviews_count  \
# count  26143.000000          44815.000000                   30075.000000
# mean      69.799143             11.326899                       9.131106
# std       12.706241             15.506038                      13.825161
# min       11.000000              1.000000                       1.000000
# 25%       63.000000              2.000000                       1.000000
# 50%       72.000000              5.000000                       4.000000
# 75%       79.000000             14.000000                      10.000000
# max       99.000000            154.000000                     143.000000
#
#        mixed_critic_reviews_count  negative_critic_reviews_count  \
# count                35442.000000                   14268.000000
# mean                     5.309294                       2.695402
# std                      6.382836                       3.404570
# ...

# %%
# Number of null values in the datasets
df.isna().sum()
# Out:
# link                                  0
# name                                250
# developer                          2781
# publisher                           384
# summary                           42250
# genres                                0
# rating                           117889
# platform                              0
# release_date                       9478
# metascore                        149480
# critic_reviews_count             130808
# positive_critic_reviews_count    145548
# mixed_critic_reviews_count       140181
# negative_critic_reviews_count    161355
# user_score                       145325
# user_reviews_count               140903
# positive_user_reviews_count      143472
# mixed_user_reviews_count         147248
# negative_user_reviews_count      146549
# dtype: int64

# %%
# Percentage of missing null values in the datasets
(df.isna().sum()/ df.shape[0]) * 100
# Out:
# link                              0.000000
# name                              0.142350
# developer                         1.583506
# publisher                         0.218650
# summary                          24.057213
# genres                            0.000000
# rating                           67.126174
# platform                          0.000000
# release_date                      5.396787
# metascore                        85.114137
# critic_reviews_count             74.482272
# positive_critic_reviews_count    82.875250
# mixed_critic_reviews_count       79.819272
# negative_critic_reviews_count    91.875779
# user_score                       82.748273
# user_reviews_count               80.230380
# positive_user_reviews_count      81.693172
# mixed_user_reviews_count         83.843232
# negative_user_reviews_count      83.445221
# dtype: float64

# %%
# Plotting the Percentage of missing null values in the datasets
((df.isna().sum()/ df.shape[0]) * 100).plot(kind= "bar")
# Out:
# <Axes: >

# %%
# Number of duplicated values in the datasets
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Preprocessing

# %%
df.head(3)
# Out:
#                                                 link                name  \
# 0     https://www.metacritic.com/game/sheep-village/       Sheep Village
# 1    https://www.metacritic.com/game/botball-online/      Botball Online
# 2  https://www.metacritic.com/game/far-cry-collec...  Far Cry Collection
#
#             developer           publisher  \
# 0             Success             Success
# 1  Sm4rt Game Studios  Sm4rt Game Studios
# 2    Ubisoft Montreal             Ubisoft
#
#                                              summary         genres rating  \
# 0                                                NaN  Miscellaneous    NaN
# 1  Botball is a smash-mouth, blastastic, five-on-...         Sports    NaN
# 2  FARCRY COLLECTION  Far Cry You are Jack Carver...    Compilation    NaN
#
#   platform release_date  metascore  critic_reviews_count  \
# 0       PC          NaN        NaN                   NaN
# 1       PC          NaN        NaN                   NaN
# ...

# %% [markdown]
# # Categorical Data Analysis

# %% [markdown]
# ## Genres

# %%
# Various types of Genre in the Dataset
df["genres"].value_counts()
# Out:
# genres
# Adventure        12437
# Visual Novel     11265
# 2D Platformer    10903
# Action            7208
# Puzzle            5534
#                  ...
# Hockey              72
# Surfing             54
# Racing Sim          19
# Console             18
# Hardware             1
# Name: count, Length: 122, dtype: int64

# %%
# Fetching the top 10 Genres of Games
df["genres"].value_counts().head(15)
# Out:
# genres
# Adventure                 12437
# Visual Novel              11265
# 2D Platformer             10903
# Action                     7208
# Puzzle                     5534
# Action Adventure           4803
# Compilation                4763
# FPS                        4643
# Top-Down Shoot-'Em-Up      4122
# First-Person Adventure     3953
# Action Puzzle              3794
# Survival                   3513
# Strategy                   3457
# JRPG                       3348
# Board                      3334
# Name: count, dtype: int64

# %%
# Calculating the percentage of the Games Genres by the top 20 Genres

(df["genres"].value_counts().head(20)/ df["genres"].shape[0]) * 100
# Out:
# genres
# Adventure                 7.081646
# Visual Novel              6.414308
# 2D Platformer             6.208185
# Action                    4.104246
# Puzzle                    3.151068
# Action Adventure          2.734835
# Compilation               2.712059
# FPS                       2.643731
# Top-Down Shoot-'Em-Up     2.347073
# First-Person Adventure    2.250844
# Action Puzzle             2.160309
# Survival                  2.000307
# Strategy                  1.968421
# JRPG                      1.906356
# Board                     1.898385
# Arcade                    1.838028
# Action RPG                1.795892
# Edutainment               1.682581
# Hidden Object             1.655820
# Auto Racing               1.510622
# Name: count, dtype: float64

# %%
# Plotting Bar Graph of top 10 Game Genres

df["genres"].value_counts().head(15).plot(kind = "bar")
# Out:
# <Axes: xlabel='genres'>

# %%
# Plotting line Graph of top 10 Game Genres

plt.figure(figsize=(10, 6))
df["genres"].value_counts().head(15).plot()
plt.xticks(rotation = "vertical")
plt.show()

# %%
# Plotting pie chart of the Game Genres

genres = df["genres"].value_counts().head(10)
plt.pie(genres, autopct = "%0.1f%%", labels=genres.index, rotatelabels= True)
plt.show()

# %% [markdown]
# ## Publisher

# %%
df.head(3)
# Out:
#                                                 link                name  \
# 0     https://www.metacritic.com/game/sheep-village/       Sheep Village
# 1    https://www.metacritic.com/game/botball-online/      Botball Online
# 2  https://www.metacritic.com/game/far-cry-collec...  Far Cry Collection
#
#             developer           publisher  \
# 0             Success             Success
# 1  Sm4rt Game Studios  Sm4rt Game Studios
# 2    Ubisoft Montreal             Ubisoft
#
#                                              summary         genres rating  \
# 0                                                NaN  Miscellaneous    NaN
# 1  Botball is a smash-mouth, blastastic, five-on-...         Sports    NaN
# 2  FARCRY COLLECTION  Far Cry You are Jack Carver...    Compilation    NaN
#
#   platform release_date  metascore  critic_reviews_count  \
# 0       PC          NaN        NaN                   NaN
# 1       PC          NaN        NaN                   NaN
# ...

# %%
# Different publishers in the Dataset

df["publisher"].value_counts()
# Out:
# publisher
# Big Fish Games            2672
# Ubisoft                   2134
# Electronic Arts           2054
# Bandai Namco Games        1643
# Sega                      1639
#                           ...
# CRAVA,Inc.                   1
# Daniel Michaneck             1
# Live the VR                  1
# Freddols                     1
# PadWorld Entertainment       1
# Name: count, Length: 43148, dtype: int64

# %%
# Top 20 publishers in the Dataset

df["publisher"].value_counts().head(20)
# Out:
# publisher
# Big Fish Games                            2672
# Ubisoft                                   2134
# Electronic Arts                           2054
# Bandai Namco Games                        1643
# Sega                                      1639
# Konami                                    1565
# Activision                                1454
# Microsoft Game Studios                    1422
# Square Enix                               1252
# Capcom                                    1070
# Nintendo                                  1066
# Hamster                                    994
# EastAsiaSoft                               962
# Ratalaika Games                            960
# THQ                                        894
# D3Publisher                                654
# Warner Bros. Interactive Entertainment     639
# Limited Run Games                          591
# Koei Tecmo Games                           584
# SCEE                                       572
# ...

# %%
# Calculating the percentage of the Games published by the top 20 publishers

(df["publisher"].value_counts().head(20)/ df["publisher"].shape[0]) * 100
# Out:
# publisher
# Big Fish Games                            1.521441
# Ubisoft                                   1.215103
# Electronic Arts                           1.169551
# Bandai Namco Games                        0.935527
# Sega                                      0.933249
# Konami                                    0.891113
# Activision                                0.827910
# Microsoft Game Studios                    0.809689
# Square Enix                               0.712891
# Capcom                                    0.609260
# Nintendo                                  0.606982
# Hamster                                   0.565985
# EastAsiaSoft                              0.547764
# Ratalaika Games                           0.546625
# THQ                                       0.509045
# D3Publisher                               0.372389
# Warner Bros. Interactive Entertainment    0.363848
# Limited Run Games                         0.336516
# ...

# %%
df["publisher"].shape
# Out:
# (175623,)

# %%
top_20_publishers = df["publisher"].value_counts().head(20)

# %%
# Plotting Bar Graph of the Top 20 Publishers

top_20_publishers.plot(kind = "bar")
plt.show()

# %%
# Plotting Pie Chart of the Top 20 Publishers

top_20_publishers.plot(kind = "pie", rotatelabels = True, label = "", autopct = "%0.1f%%")

plt.show()

# %%
# Plotting line chart of top 20 Publishers

plt.figure(figsize= (15, 10))
top_20_publishers.plot()
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Developer

# %%
df.head(3)
# Out:
#                                                 link                name  \
# 0     https://www.metacritic.com/game/sheep-village/       Sheep Village
# 1    https://www.metacritic.com/game/botball-online/      Botball Online
# 2  https://www.metacritic.com/game/far-cry-collec...  Far Cry Collection
#
#             developer           publisher  \
# 0             Success             Success
# 1  Sm4rt Game Studios  Sm4rt Game Studios
# 2    Ubisoft Montreal             Ubisoft
#
#                                              summary         genres rating  \
# 0                                                NaN  Miscellaneous    NaN
# 1  Botball is a smash-mouth, blastastic, five-on-...         Sports    NaN
# 2  FARCRY COLLECTION  Far Cry You are Jack Carver...    Compilation    NaN
#
#   platform release_date  metascore  critic_reviews_count  \
# 0       PC          NaN        NaN                   NaN
# 1       PC          NaN        NaN                   NaN
# ...

# %%
# Different developers in the Dataset

df["developer"].value_counts()
# Out:
# developer
# Various                   997
# Capcom                    777
# Big Fish Games            739
# Konami                    720
# Hamster                   556
#                          ...
# Halfheartd Games            1
# Rotciv Ocnarb               1
# Output Games                1
# High Five Studios LLC       1
# PadWorld Entertainment      1
# Name: count, Length: 49934, dtype: int64

# %%
# Top 20 developers in the Dataset

df["developer"].value_counts().head(20)
# Out:
# developer
# Various               997
# Capcom                777
# Big Fish Games        739
# Konami                720
# Hamster               556
# Bandai Namco Games    526
# Arc System Works      518
# Telltale Games        515
# Ubisoft               462
# Sega                  410
# Zen Studios           369
# Nintendo              368
# EA Sports             324
# Electronic Arts       310
# Square Enix           303
# Koei Tecmo Games      299
# Ubisoft Montreal      296
# Omega Force           274
# Maxis                 267
# EA Canada             263
# Name: count, dtype: int64

# %%
# Calculating the percentage of the Games developed by the top 20 developers

(df["developer"].value_counts().head(20)/ df["developer"].shape[0]) * 100
# Out:
# developer
# Various               0.567693
# Capcom                0.442425
# Big Fish Games        0.420788
# Konami                0.409969
# Hamster               0.316587
# Bandai Namco Games    0.299505
# Arc System Works      0.294950
# Telltale Games        0.293242
# Ubisoft               0.263063
# Sega                  0.233455
# Zen Studios           0.210109
# Nintendo              0.209540
# EA Sports             0.184486
# Electronic Arts       0.176514
# Square Enix           0.172529
# Koei Tecmo Games      0.170251
# Ubisoft Montreal      0.168543
# Omega Force           0.156016
# Maxis                 0.152030
# EA Canada             0.149753
# Name: count, dtype: float64

# %%
df["publisher"].shape
# Out:
# (175623,)

# %%
top_20_developers = df["developer"].value_counts().head(20)

# %%
# Plotting Bar Graph of the Top 20 Developers

top_20_developers.plot(kind = "bar")
plt.show()

# %%
# Plotting line chart of top 20 Developers

plt.figure(figsize= (15, 10))
top_20_developers.plot()
plt.xticks(rotation = 45)
plt.show()

# %%
# Plotting Pie Chart of the Top 10 Developers

top_20_publishers.head(10).plot(kind = "pie", rotatelabels = True, label = "", autopct = "%0.2f%%")

plt.show()

# %% [markdown]
# ## Platform

# %%
df.sample(2)
# Out:
#                                                      link  \
# 67983       https://www.metacritic.com/game/the-deletion/
# 152624  https://www.metacritic.com/game/lego-builders-...
#
#                           name    developer   publisher  \
# 67983             The Deletion    Russpuppy   Russpuppy
# 152624  LEGO Builder's Journey  Light Brick  LEGO Games
#
#                                                   summary         genres  \
# 67983                                                 NaN  2D Platformer
# 152624  A story about play, connections and adventure....         Puzzle
#
#        rating       platform      release_date  metascore  \
# 67983     NaN             PC  30-07-2015 00:00        NaN
# 152624    NaN  Xbox Series X  25-11-2021 00:00        NaN
#
#         critic_reviews_count  positive_critic_reviews_count  \
# 67983                    NaN                            NaN
# 152624                   1.0                            1.0
#
# ...

# %%
# Different Platforms in the Dataset

df["platform"].value_counts()
# Out:
# platform
# PC                   102067
# Nintendo Switch       11707
# PlayStation 4         10134
# Xbox One               7259
# Xbox 360               6081
# PlayStation 2          4366
# PlayStation            4294
# DS                     4268
# iOS (iPhone/iPad)      3270
# PlayStation 3          3269
# PlayStation 5          2845
# PlayStation Vita       2193
# PSP                    2168
# Xbox Series X          2064
# Wii                    1967
# 3DS                    1876
# Game Boy Advance       1622
# Xbox                   1075
# Wii U                   830
# GameCube                728
# Dreamcast               726
# Meta Quest              444
# Nintendo 64             370
# Name: count, dtype: int64

# %%
# Number of dfferent types of platforms in the dataset
df["platform"].value_counts().count()
# Out:
# 23

# %%
# Calculating the percentage of the Games published on these platforms 

(df["platform"].value_counts().head(20)/ df["platform"].shape[0]) * 100
# Out:
# platform
# PC                   58.117103
# Nintendo Switch       6.665983
# PlayStation 4         5.770315
# Xbox One              4.133286
# Xbox 360              3.462531
# PlayStation 2         2.486007
# PlayStation           2.445010
# DS                    2.430206
# iOS (iPhone/iPad)     1.861943
# PlayStation 3         1.861374
# PlayStation 5         1.619947
# PlayStation Vita      1.248697
# PSP                   1.234462
# Xbox Series X         1.175245
# Wii                   1.120013
# 3DS                   1.068197
# Game Boy Advance      0.923569
# Xbox                  0.612107
# Wii U                 0.472603
# GameCube              0.414524
# Name: count, dtype: float64

# %%
platforms = df["platform"].value_counts()

# %%
# Plotting Bar Graph of the different types of platforms in the dataset

platforms.plot(kind = "bar")
plt.show()

# %%
# Plotting line chart of the different types of platforms in the dataset

plt.figure(figsize= (15, 10))
platforms.plot()
plt.xticks(rotation = 45)
plt.show()

# %%
# Plotting Pie chart of the top 15 different types of platforms in the dataset

plt.figure(figsize= (8, 8))
platforms.head(15).plot(kind = "pie", rotatelabels = True, label = "", autopct = "%0.1f%%")

plt.show()

# %% [markdown]
# ## Release Date

# %%
df.sample(2)
# Out:
#                                                      link  \
# 153713   https://www.metacritic.com/game/puppy-adventure/
# 141236  https://www.metacritic.com/game/noroi-no-game-...
#
#                        name        developer        publisher  \
# 153713      Puppy Adventure  GreatHopeStudio  GreatHopeStudio
# 141236  Noroi no Game: Goku      Square Enix      Square Enix
#
#                                                   summary             genres  \
# 153713  Puppy Adventure - Top Down View game with role...  Open-World Action
# 141236                                                NaN      2D Platformer
#
#        rating platform      release_date  metascore  critic_reviews_count  \
# 153713    NaN       PC  23-05-2021 00:00        NaN                   NaN
# 141236    NaN       DS  09-09-2009 00:00        NaN                   NaN
#
#         positive_critic_reviews_count  mixed_critic_reviews_count  \
# 153713                            NaN                         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175623 entries, 0 to 175622
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   link                           175623 non-null  object
#  1   name                           175373 non-null  object
#  2   developer                      172842 non-null  object
#  3   publisher                      175239 non-null  object
#  4   summary                        133373 non-null  object
#  5   genres                         175623 non-null  object
#  6   rating                         57734 non-null   object
#  7   platform                       175623 non-null  object
#  8   release_date                   166145 non-null  object
#  9   metascore                      26143 non-null   float64
#  10  critic_reviews_count           44815 non-null   float64
#  11  positive_critic_reviews_count  30075 non-null   float64
# ...

# %%
# Change the release_date column to datetime

df["release_date"] = pd.to_datetime(df["release_date"])
# Out:
# C:\Users\DIWAKAR SINGH\AppData\Local\Temp\ipykernel_18768\3867665964.py:3: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["release_date"] = pd.to_datetime(df["release_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175623 entries, 0 to 175622
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   link                           175623 non-null  object
#  1   name                           175373 non-null  object
#  2   developer                      172842 non-null  object
#  3   publisher                      175239 non-null  object
#  4   summary                        133373 non-null  object
#  5   genres                         175623 non-null  object
#  6   rating                         57734 non-null   object
#  7   platform                       175623 non-null  object
#  8   release_date                   166145 non-null  datetime64[ns]
#  9   metascore                      26143 non-null   float64
#  10  critic_reviews_count           44815 non-null   float64
#  11  positive_critic_reviews_count  30075 non-null   float64
# ...

# %%
df.sample(2)
# Out:
#                                                      link  \
# 113128  https://www.metacritic.com/game/entre-planos-u...
# 107860  https://www.metacritic.com/game/cruise-control...
#
#                                                   name  \
# 113128  Entre Planos: Um cafezinho para o fim do mundo
# 107860                         Cruise Control Mode On!
#
#                               developer                        publisher  \
# 113128  RENEGADOS PRODUZINDO GAMES LTDA  RENEGADOS PRODUZINDO GAMES LTDA
# 107860                    Atomic Fabrik                    Atomic Fabrik
#
#                                                   summary         genres  \
# 113128  In a tedious day, Oliver finishes his best inv...  2D Platformer
# 107860                         This is about adrenaline.          Arcade
#
#        rating platform release_date  metascore  critic_reviews_count  \
# 113128    NaN       PC   2022-08-11        NaN                   NaN
# ...

# %%
year_of_relese_date = df["release_date"].dt.year.value_counts()

# %%
# Total Number of games published in particular years
year_of_relese_date
# Out:
# release_date
# 2023.0    18594
# 2022.0    16231
# 2021.0    14437
# 2020.0    12581
# 2018.0    11371
# 2019.0    11312
# 2017.0     9296
# 2016.0     7144
# 2015.0     5929
# 2014.0     5188
# 2010.0     5078
# 2009.0     5040
# 2011.0     4939
# 2013.0     4733
# 2008.0     3703
# 2012.0     3664
# 2007.0     3389
# 2006.0     3148
# 2005.0     2778
# 2002.0     2728
# 2003.0     2543
# 2004.0     2443
# 2001.0     2209
# 2000.0     2146
# 1999.0     1654
# 1998.0     1267
# 1997.0     1043
# 1996.0      864
# 1995.0      307
# 2024.0      105
# 1994.0       73
# 1993.0       57
# 1992.0       32
# 1991.0       31
# 1990.0       25
# 1989.0       18
# 1988.0       11
# 1987.0        9
# 1984.0        9
# 1986.0        4
# 1983.0        4
# 1982.0        3
# 1985.0        2
# 1970.0        2
# 1981.0        1
# Name: count, dtype: int64

# %%
# Number of years data we have?

year_of_relese_date.count()
# Out:
# 45

# %%
# Plotting Bar Graph of years which published highest number of games

plt.figure(figsize=(15, 10))
year_of_relese_date.head(20).plot(kind = "bar")
plt.xticks(rotation = 45)
plt.show()

# %%
# Plotting Line chart of years which published highest number of games

plt.figure(figsize= (15, 10))
year_of_relese_date.head(20).plot()
plt.xticks(rotation = 45)
plt.show()

# %%
# Plotting Pie Chart of years which published highest number of games

plt.figure(figsize=(10, 10))
year_of_relese_date.head(20).plot(kind = "pie", rotatelabels = True, label = "", autopct = "%0.1f%%")

plt.show()
